# %%
import numpy as np

# %%
import pandas as pd

# %%
df= pd.read_csv('en.csv')

# %%
df.head(5)
# Out:
#    age  gender  rewe edu  pur
# 0   89  female  good  ug  yes
# 1   24  female  aerg  pg  yes
# 2   34  female  poor  pg   no
# 3   18  female  poor  pg  yes
# 4   16  female  aerg  ug   no

# %%
dft= df.iloc[:,2:]

# %%
dft
# Out:
#     rewe    edu  pur
# 0   good     ug  yes
# 1   aerg     pg  yes
# 2   poor     pg   no
# 3   poor     pg  yes
# 4   aerg     ug   no
# 5   good  shool  yes
# 6   aerg  shool   no
# 7   aerg     ug  yes
# 8   poor  shool  yes
# 9   good     pg   no
# 10  aerg  shool  yes
# 11  aerg     ug   no
# 12  poor     ug  yes
# 13  poor  shool  yes

# %%
from sklearn .model_selection import train_test_split

# %%
a_train,a_test,y_train,y_test = train_test_split(dft.iloc[:,0:2],dft.iloc[:,-1],test_size=0.2)

# %%
a_train
# Out:
#     rewe    edu
# 9   good     pg
# 13  poor  shool
# 11  aerg     ug
# 7   aerg     ug
# 2   poor     pg
# 1   aerg     pg
# 8   poor  shool
# 10  aerg  shool
# 5   good  shool
# 12  poor     ug
# 4   aerg     ug

# %%
a_test
# Out:
#    rewe    edu
# 6  aerg  shool
# 3  poor     pg
# 0  good     ug

# %%
y_test
# Out:
# 9      no
# 12    yes
# 13    yes
# Name: pur, dtype: object

# %%
from sklearn .preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['poor','aerg','good'],['shool','ug','pg']])

# %%
oe.fit(a_train)
# Out:
# OrdinalEncoder(categories=[['poor', 'aerg', 'good'], ['shool', 'ug', 'pg']])

# %%
a_train = oe.transform(a_train)
a_test = oe.transform(a_test)

# %%
a_train
# Out:
# array([[2., 2.],
#        [0., 0.],
#        [1., 1.],
#        [1., 1.],
#        [0., 2.],
#        [1., 2.],
#        [0., 0.],
#        [1., 0.],
#        [2., 0.],
#        [0., 1.],
#        [1., 1.]])

# %%
a_test
# Out:
# array([[1., 0.],
#        [0., 2.],
#        [2., 1.]])

# %% [markdown]
# # labelen

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
y_train
# Out:
# 4      no
# 11     no
# 1     yes
# 5     yes
# 2      no
# 0     yes
# 3     yes
# 6      no
# 10    yes
# 7     yes
# 8     yes
# Name: pur, dtype: object

# %%
le .fit(y_train)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_train
# Out:
# array([0, 0, 1, 1, 0, 1, 1, 0, 1, 1, 1])

# %%
y_test
# Out:
# array([0, 1, 1])
